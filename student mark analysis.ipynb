# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Student.csv')
df.shape
df.info
df.columns=['gender','group','education','lunch','course','maths','reading score','writing score']
df.tail(30)
df.reset_index()
df.set_index('education').sort_values('group',ascending=False)
# df['female']=df['gender']=='female'
# df['male']=df['gender']=='male'
df['gender'].unique()
df.set_index('gender').sort_values('group',ascending=False)
df.isnull().sum()
df1=df[df['gender']=='female']
df2=df[df['gender']=='male']
df1['total']=df1['maths']+df1['reading score']+df1['writing score']
df1['average']=df1['total']/3
df1
df2['total']=df2['maths']+df2['reading score']+df2['writing score']
df2['average']=df2['total']/3
df2.set_index('gender')
df3=pd.merge(df1,df2,on=['education'])
df
# df.groupby(['gender'])
# Out:
# <ipython-input-144-c301e3cc53e9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['total']=df1['maths']+df1['reading score']+df1['writing score']
# <ipython-input-144-c301e3cc53e9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['average']=df1['total']/3
# <ipython-input-144-c301e3cc53e9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.countplot(df['gender'])
sns.countplot(df['education'])
plt.xticks(rotation=90)
# Out:
# C:\Users\P.Vijay Srinivasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\P.Vijay Srinivasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %%
plt.barh(df2['education'],df2['average'])
plt.ylabel('education')
plt.xlabel('average')
plt.xticks(rotation=90)
df2[df2['education']=='some high school']['average'].mean()
# Out:
# 64.6363636363636

# %%
sns.countplot(data=df,x='gender',hue='maths')
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), [Text(0, 0, 'female'), Text(1, 0, 'male')])

# %%
fig,ax=plt.subplots(1,1,figsize=(10,10))
plt.subplot(3,1,1)
x=sns.barplot('education','maths',hue='gender',data=df)
plt.subplot(3,1,2)
y=sns.barplot('education','reading score',hue='gender',data=df)
plt.subplot(3,1,3)
z=sns.barplot('education','writing score',hue='gender',data=df)


# barplot('education',i,'gender')
# Out:
# C:\Users\P.Vijay Srinivasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\P.Vijay Srinivasan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.pairplot(df1,hue='education',vars=['maths','reading score','writing score'])
plt.show()

# %%
sns.heatmap(df2.corr(),annot=True,fmt='.3f')
# Out:
# <AxesSubplot:>

# %%
for i in ('maths','reading score','writing score'):
    sns.barplot(x='education',y=i,data=df1)
    plt.xticks(rotation=90)

# %%
plt.subplot(2,1,1)

plt.plot(df2['average'],df2['maths'],'^',color='red',label='boys average')
plt.subplot(2,1,2)
plt.plot(df1['average'],df1['total'],'o',color='blue',label='girls average')
plt.figure(figsize=(20,20))
plt.show()
